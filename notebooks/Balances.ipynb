# %%
include("../src-fig/plotting.jl")
include("../setup/ensemble.jl");
# Out:
# [ Info: Oceananigans will use 4 threads

# %%
include("../src-fig/figures/UBALANCE.jl")
include("../src-fig/figures/VBALANCE.jl")
include("../src-fig/figures/BBALANCE.jl")
# Out:
# terms_BBALANCE (generic function with 1 method)

# %% [markdown]
# # Across-front velocity

# %%
check_UBALANCE(test_set.filenames[1]; N_window=5)

# %%
terms_UBALANCE(test_set.filenames[1], range(1, 20, 300), "../figures/video/test_UBALANCE.mp4"; N_window=5)
# Out:
# 1059s / 1059s (300 / 300)

# %% [markdown]
# # Buoyancy

# %%
check_BBALANCE(test_set.filenames[1]; N_window=5)

# %%
terms_BBALANCE(test_set.filenames[1], range(1, 20, 300), "../figures/video/test_BBALANCE.mp4"; N_window=5)
# Out:
# 986s / 1060s (279 / 300)

# %% [markdown]
# # Along-front velocity

# %%
check_VBALANCE(test_set.filenames[1]; N_window=5)

# %%
terms_VBALANCE(test_set.filenames[1], range(1, 20, 300), "../figures/video/test_VBALANCE.mp4"; N_window = 5)
# Out:
# 899s / 899s (300 / 300)
