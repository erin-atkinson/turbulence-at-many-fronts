# %%
include("../src-fig/plotting.jl")
include("../setup/ensemble.jl")

include("../src-fig/figures/MEAN.jl")
# Out:
# [ Info: Oceananigans will use 4 threads
# mean_hovmoller (generic function with 1 method)

# %% [markdown]
# Plots of the mean fields

# %%
# Configure
simulation_set = test_set
run_id = test_set.filenames[3]
foldername = joinpath(scratchpath, run_id)
# Out:
# "/home/atkin163/scratch/turbulence-at-many-fronts/0_1-0_1-0_1-0_0-C"

# %%
filename = joinpath("../figures/video", "MEAN-$run_id.mp4")

mean_fields(foldername, range(1, 100, 300), filename;
    fig_kw = NamedTuple(),
    ax_kw = NamedTuple(),
    record_kw = (; px_per_unit=2, framerate=12),
    background = true,
    N_window = 1
    )
# Out:
# 576s / 576s (300 / 300)
