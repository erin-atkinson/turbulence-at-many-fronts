# %%
using Oceananigans
using CairoMakie
using CairoMakie.Colors
using Statistics
using Printf
using FFTW

using JLD2
include("../src-fig/plotting.jl")

# %% [markdown]
# # Varying central region size

# %% [markdown]
# ## Final state snapshots

# %% [markdown]
# ## Hovmoller plots

# %% [markdown]
# ## Spectra

# %% [markdown]
# # Varying horizontal resolution

# %% [markdown]
# ## Final state snapshots

# %% [markdown]
# ## Hovmoller plots

# %% [markdown]
# ## Spectra
